# %% [markdown]
# <a href="https://colab.research.google.com/github/PariyantoNoviansyah/Fluxion/blob/master/YOLOv5_Custom_Code_Train_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.0-237-gdc7e093 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.2/78.2 GB disk)

# %%
# !unzip -u "/content/gdrive/My Drive/TrainData/train_data.zip" -d "/content/"
# Out:
# Archive:  /content/gdrive/My Drive/TrainData/train_data.zip
#    creating: /content/train_data/images/
#    creating: /content/train_data/images/train/
#   inflating: /content/train_data/images/train/train_0057_S=1.jpg
#   inflating: /content/train_data/images/train/train_0077_C=2.jpg
#   inflating: /content/train_data/images/train/train_0081_C=2.jpg
#   inflating: /content/train_data/images/train/train_0082_C=1.jpg
#   inflating: /content/train_data/images/train/train_0085_C=1.jpg
#   inflating: /content/train_data/images/train/train_0086_C=2.jpg
#   inflating: /content/train_data/images/train/train_0087_C=2.jpg
#   inflating: /content/train_data/images/train/train_0089_C=2.jpg
#   inflating: /content/train_data/images/train/train_0091_C=2.jpg
#   inflating: /content/train_data/images/train/train_0092_C=2.jpg
#   inflating: /content/train_data/images/train/train_0093_C=3.jpg
#   inflating: /content/train_data/images/train/train_0113_S=1.jpg
# ...

# %%
# Train YOLOv5s on custom_data for 70 epochs
# !python train.py --img 640 --batch 16 --epochs 700 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=700, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-237-gdc7e093 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source ../testing.mp4
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=../testing.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-237-gdc7e093 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562dc8696600] Detected moov in a free atom.
# video 1/1 (1/2114) /content/testing.mp4: 384x640 1 Commelina sp., 1 Eleusine sp., Done. (0.019s)
# video 1/1 (2/2114) /content/testing.mp4: 384x640 1 Ageratum sp., 1 Eleusine sp., Done. (0.016s)
# ...
